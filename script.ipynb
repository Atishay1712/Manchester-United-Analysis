# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import codecs
import pandas as pd
import os

def folder_creation(league):
    if not os.path.isdir(league):
        os.mkdir(league)
        

def get_script(url):
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception("Response was code " + str(response.status_code))
    html = response.text
    parsed_html = BeautifulSoup(html, 'html.parser')
    scripts = parsed_html.findAll('script')
    filtered_scripts = []
    for script in scripts:
        if len(script.contents) > 0:
            filtered_scripts += [script]
    return scripts

def get_team(url):
    scripts = get_script(url)
    teamData = {}
    playerData = {}
    for script in scripts:
        for c in script.contents:
            split_data = c.split('=')
            data = split_data[0].strip()
            if data == 'var teamsData':
                content = re.findall(r'JSON\.parse\(\'(.*)\'\)',split_data[1])
                decoded_content = codecs.escape_decode(content[0], "hex")[0].decode('utf-8')
                teamData = json.loads(decoded_content)
            elif data == 'var playersData':
                content = re.findall(r'JSON\.parse\(\'(.*)\'\)',split_data[1])
                decoded_content = codecs.escape_decode(content[0], "hex")[0].decode('utf-8')
                playerData = json.loads(decoded_content)
    return teamData, playerData

def parse_league_data(league,year):
    url = f"https://understat.com/league/{league}/{year}"
    folder_creation(league)
    year_folder = os.path.join(league,year)
    folder_creation(year_folder)
    
    teamData,playerData = get_team(url)
    new_team_data = []
    for t,v in teamData.items():
        new_team_data += [v]
    for data in new_team_data:
        team_frame = pd.DataFrame.from_records(data["history"])
        team = data["title"].replace(' ', '_')
        
        team_frame.to_csv(os.path.join(year_folder,team) + ".csv", index=False)
    player_frame = pd.DataFrame.from_records(playerData)

    player_frame.to_csv(os.path.join(year_folder,year) + 'understat_player.csv', index=False)

def main():
    leagues = ["EPL", "La_liga", "Bundesliga", "Serie_A", "Ligue_1"]
    years = ["2014", "2015", "2016", "2017", "2018", "2019"]
    for league in leagues:
        for year in years:
            parse_league_data(league,year)

if __name__ == '__main__':
    main()

# %%
def get_player_data(url):
    scripts = get_url(url)
    teamData = {}
    playerData = {}
    for script in scripts:
        for c in script.contents:
            split_data = c.split('=')
            data = split_data[0].strip()
            if data == 'var playersData':
                content = re.findall(r'JSON\.parse\(\'(.*)\'\)',split_data[1])
                decoded_content = codecs.escape_decode(content[0], "hex")[0].decode('utf-8')
                playerData = json.loads(decoded_content)
    return playerData

# %%
get_player_data("https://understat.com/league/La_liga/2018")
# Out:
# [{'id': '2097',
#   'player_name': 'Lionel Messi',
#   'games': '34',
#   'time': '2704',
#   'goals': '36',
#   'xG': '25.997169069945812',
#   'assists': '13',
#   'xA': '15.33516551926732',
#   'shots': '170',
#   'key_passes': '93',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Barcelona',
#   'npg': '32',
#   'npxG': '22.28090887516737',
#   'xGChain': '38.45987746119499',
#   'xGBuildup': '10.69879900291562'},
#  {'id': '2098',
#   'player_name': 'Luis Suárez',
#   'games': '33',
#   'time': '2832',
#   'goals': '21',
#   'xG': '24.39443599805236',
#   'assists': '6',
#   'xA': '7.323390703648329',
#   'shots': '112',
#   'key_passes': '47',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Barcelona',
#   'npg': '17',
#   'npxG': '21.421453412622213',
#   'xGChain': '36.808273531496525',
#   'xGBuildup': '12.378092227503657'},
#  {'id': '2370',
#   'player_name': 'Karim Benzema',
#   'games': '36',
#   'time': '2972',
#   'goals': '21',
#   'xG': '18.669334318488836',
#   'assists': '6',
#   'xA': '6.1459240317344666',
#   'shots': '104',
#   'key_passes': '48',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Madrid',
#   'npg': '18',
#   'npxG': '16.439501460641623',
#   'xGChain': '27.201730754226446',
#   'xGBuildup': '8.029114556498826'},
#  {'id': '2290',
#   'player_name': 'Iago Aspas',
#   'games': '27',
#   'time': '2268',
#   'goals': '20',
#   'xG': '12.470295615494251',
#   'assists': '6',
#   'xA': '6.623374821618199',
#   'shots': '70',
#   'key_passes': '56',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Celta Vigo',
#   'npg': '15',
#   'npxG': '8.753907531499863',
#   'xGChain': '18.57387538999319',
#   'xGBuildup': '5.864633502438664'},
#  {'id': '1709',
#   'player_name': 'Cristhian Stuani',
#   'games': '32',
#   'time': '2736',
#   'goals': '19',
#   'xG': '14.402687706053257',
#   'assists': '0',
#   'xA': '0.6400149874389172',
#   'shots': '79',
#   'key_passes': '14',
#   'yellow_cards': '9',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Girona',
#   'npg': '14',
#   'npxG': '10.68655527383089',
#   'xGChain': '12.934033576399088',
#   'xGBuildup': '4.393606349825859'},
#  {'id': '3210',
#   'player_name': 'Wissam Ben Yedder',
#   'games': '35',
#   'time': '2823',
#   'goals': '18',
#   'xG': '18.917882565408945',
#   'assists': '9',
#   'xA': '7.872443415224552',
#   'shots': '76',
#   'key_passes': '45',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Sevilla',
#   'npg': '16',
#   'npxG': '17.43132734671235',
#   'xGChain': '28.544353917241096',
#   'xGBuildup': '9.956073679029942'},
#  {'id': '2543',
#   'player_name': 'Borja Iglesias',
#   'games': '37',
#   'time': '3095',
#   'goals': '17',
#   'xG': '15.842947600409389',
#   'assists': '3',
#   'xA': '4.824147495441139',
#   'shots': '89',
#   'key_passes': '41',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Espanyol',
#   'npg': '14',
#   'npxG': '13.613114787265658',
#   'xGChain': '19.68051299266517',
#   'xGBuildup': '3.1604582518339157'},
#  {'id': '2270',
#   'player_name': 'Antoine Griezmann',
#   'games': '37',
#   'time': '3213',
#   'goals': '15',
#   'xG': '14.60985544603318',
#   'assists': '8',
#   'xA': '8.838093780912459',
#   'shots': '113',
#   'key_passes': '74',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Atletico Madrid',
#   'npg': '12',
#   'npxG': '12.380150402896106',
#   'xGChain': '20.534598607569933',
#   'xGBuildup': '8.563468346372247'},
#  {'id': '2155',
#   'player_name': 'Jorge Molina',
#   'games': '38',
#   'time': '2657',
#   'goals': '14',
#   'xG': '11.42651876527816',
#   'assists': '5',
#   'xA': '6.8675405932590365',
#   'shots': '57',
#   'key_passes': '44',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Getafe',
#   'npg': '12',
#   'npxG': '9.94361284095794',
#   'xGChain': '16.507737524807453',
#   'xGBuildup': '3.672793222591281'},
#  {'id': '2339',
#   'player_name': 'Charles',
#   'games': '34',
#   'time': '1732',
#   'goals': '14',
#   'xG': '12.790910931304097',
#   'assists': '1',
#   'xA': '1.5539405588060617',
#   'shots': '63',
#   'key_passes': '15',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Eibar',
#   'npg': '8',
#   'npxG': '7.587967375293374',
#   'xGChain': '10.08357304520905',
#   'xGBuildup': '2.5883562490344048'},
#  {'id': '4229',
#   'player_name': 'Raúl de Tomás',
#   'games': '33',
#   'time': '2822',
#   'goals': '14',
#   'xG': '15.146002831868827',
#   'assists': '1',
#   'xA': '1.725691075436771',
#   'shots': '115',
#   'key_passes': '19',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '14',
#   'npxG': '15.146002831868827',
#   'xGChain': '16.361451391130686',
#   'xGBuildup': '2.3896262403577566'},
#  {'id': '7009',
#   'player_name': 'Jaime Mata',
#   'games': '34',
#   'time': '2450',
#   'goals': '14',
#   'xG': '12.554690098389983',
#   'assists': '6',
#   'xA': '2.7390331588685513',
#   'shots': '59',
#   'key_passes': '19',
#   'yellow_cards': '10',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Getafe',
#   'npg': '10',
#   'npxG': '9.581579541787505',
#   'xGChain': '12.742755003273487',
#   'xGBuildup': '2.8516541346907616'},
#  {'id': '2234',
#   'player_name': 'Mikel Oyarzabal',
#   'games': '37',
#   'time': '3168',
#   'goals': '13',
#   'xG': '11.029313363134861',
#   'assists': '2',
#   'xA': '4.937821137718856',
#   'shots': '66',
#   'key_passes': '45',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Sociedad',
#   'npg': '10',
#   'npxG': '8.799608413130045',
#   'xGChain': '16.335075115785003',
#   'xGBuildup': '4.442267783917487'},
#  {'id': '2399',
#   'player_name': 'Iñaki Williams',
#   'games': '38',
#   'time': '3055',
#   'goals': '13',
#   'xG': '13.370236299932003',
#   'assists': '4',
#   'xA': '3.643498457968235',
#   'shots': '75',
#   'key_passes': '30',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Athletic Club',
#   'npg': '13',
#   'npxG': '13.370236299932003',
#   'xGChain': '19.539794445037842',
#   'xGBuildup': '4.114086925983429'},
#  {'id': '2566',
#   'player_name': 'Roger',
#   'games': '31',
#   'time': '1911',
#   'goals': '13',
#   'xG': '12.817432545125484',
#   'assists': '0',
#   'xA': '1.05675339512527',
#   'shots': '70',
#   'key_passes': '15',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Levante',
#   'npg': '11',
#   'npxG': '11.330877289175987',
#   'xGChain': '11.1296352930367',
#   'xGBuildup': '1.0375902689993382'},
#  {'id': '6124',
#   'player_name': 'Maxi Gómez',
#   'games': '35',
#   'time': '2962',
#   'goals': '13',
#   'xG': '12.474976568482816',
#   'assists': '5',
#   'xA': '2.9785617627203465',
#   'shots': '81',
#   'key_passes': '31',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Celta Vigo',
#   'npg': '12',
#   'npxG': '11.731698936782777',
#   'xGChain': '15.201250951737165',
#   'xGBuildup': '2.383694913238287'},
#  {'id': '2186',
#   'player_name': 'Morales',
#   'games': '37',
#   'time': '3196',
#   'goals': '12',
#   'xG': '13.04328029230237',
#   'assists': '5',
#   'xA': '5.543193655088544',
#   'shots': '65',
#   'key_passes': '43',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Levante',
#   'npg': '9',
#   'npxG': '9.32727601006627',
#   'xGChain': '17.859703842550516',
#   'xGBuildup': '5.1766180247068405'},
#  {'id': '2199',
#   'player_name': 'Pablo Sarabia',
#   'games': '33',
#   'time': '2731',
#   'goals': '12',
#   'xG': '11.995943296700716',
#   'assists': '13',
#   'xA': '11.321500762365758',
#   'shots': '74',
#   'key_passes': '67',
#   'yellow_cards': '9',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Sevilla',
#   'npg': '11',
#   'npxG': '11.252665627747774',
#   'xGChain': '27.67233020812273',
#   'xGBuildup': '10.431681127287447'},
#  {'id': '2361',
#   'player_name': 'Willian José',
#   'games': '31',
#   'time': '2376',
#   'goals': '12',
#   'xG': '11.391882727853954',
#   'assists': '5',
#   'xA': '4.122103626839817',
#   'shots': '55',
#   'key_passes': '37',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Real Sociedad',
#   'npg': '7',
#   'npxG': '6.188939304091036',
#   'xGChain': '13.282845466397703',
#   'xGBuildup': '4.503001198172569'},
#  {'id': '5657',
#   'player_name': 'Karl Toko Ekambi',
#   'games': '34',
#   'time': '2147',
#   'goals': '10',
#   'xG': '10.614568071439862',
#   'assists': '1',
#   'xA': '2.1872154027223587',
#   'shots': '59',
#   'key_passes': '26',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Villarreal',
#   'npg': '10',
#   'npxG': '9.871290432289243',
#   'xGChain': '11.669786984100938',
#   'xGBuildup': '1.9279387053102255'},
#  {'id': '6955',
#   'player_name': 'Ezequiel Ávila',
#   'games': '34',
#   'time': '1991',
#   'goals': '10',
#   'xG': '6.9964762246236205',
#   'assists': '2',
#   'xA': '3.018417902290821',
#   'shots': '89',
#   'key_passes': '21',
#   'yellow_cards': '10',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'SD Huesca',
#   'npg': '9',
#   'npxG': '6.25319857429713',
#   'xGChain': '10.493804385885596',
#   'xGBuildup': '2.719224648550153'},
#  {'id': '1672',
#   'player_name': 'Jonathan Calleri',
#   'games': '34',
#   'time': '2884',
#   'goals': '9',
#   'xG': '8.124452205374837',
#   'assists': '2',
#   'xA': '3.2726386953145266',
#   'shots': '81',
#   'key_passes': '31',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Alaves',
#   'npg': '7',
#   'npxG': '6.637896938249469',
#   'xGChain': '11.518800236284733',
#   'xGBuildup': '3.9264746885746717'},
#  {'id': '2378',
#   'player_name': 'Daniel Parejo',
#   'games': '36',
#   'time': '3068',
#   'goals': '9',
#   'xG': '7.954010252840817',
#   'assists': '7',
#   'xA': '7.291649481281638',
#   'shots': '44',
#   'key_passes': '80',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Valencia',
#   'npg': '4',
#   'npxG': '3.494472493417561',
#   'xGChain': '19.573780270293355',
#   'xGBuildup': '15.038495542481542'},
#  {'id': '2400',
#   'player_name': 'Raúl García',
#   'games': '33',
#   'time': '2384',
#   'goals': '9',
#   'xG': '8.365462431684136',
#   'assists': '3',
#   'xA': '3.3771010860800743',
#   'shots': '81',
#   'key_passes': '27',
#   'yellow_cards': '12',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Athletic Club',
#   'npg': '7',
#   'npxG': '5.3924799580127',
#   'xGChain': '10.109714029356837',
#   'xGBuildup': '3.491061568260193'},
#  {'id': '5169',
#   'player_name': 'Youssef En-Nesyri',
#   'games': '31',
#   'time': '2100',
#   'goals': '9',
#   'xG': '7.127062444575131',
#   'assists': '2',
#   'xA': '1.7204033602029085',
#   'shots': '74',
#   'key_passes': '16',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Leganes',
#   'npg': '9',
#   'npxG': '7.127062444575131',
#   'xGChain': '8.200658722780645',
#   'xGBuildup': '0.7248655958101153'},
#  {'id': '5681',
#   'player_name': 'Giovani Lo Celso',
#   'games': '32',
#   'time': '2401',
#   'goals': '9',
#   'xG': '8.157648704946041',
#   'assists': '4',
#   'xA': '4.238757798448205',
#   'shots': '64',
#   'key_passes': '27',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Betis',
#   'npg': '7',
#   'npxG': '5.184538200497627',
#   'xGChain': '13.617415504530072',
#   'xGBuildup': '6.539375353604555'},
#  {'id': '6118',
#   'player_name': 'Portu',
#   'games': '34',
#   'time': '2850',
#   'goals': '9',
#   'xG': '8.3912597540766',
#   'assists': '2',
#   'xA': '4.6105682561174035',
#   'shots': '37',
#   'key_passes': '33',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Girona',
#   'npg': '8',
#   'npxG': '7.647982085123658',
#   'xGChain': '14.360353744588792',
#   'xGBuildup': '4.635711043141782'},
#  {'id': '6170',
#   'player_name': 'André Silva',
#   'games': '27',
#   'time': '2170',
#   'goals': '9',
#   'xG': '11.227702824398875',
#   'assists': '0',
#   'xA': '4.498761082068086',
#   'shots': '63',
#   'key_passes': '29',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Sevilla',
#   'npg': '9',
#   'npxG': '11.227702824398875',
#   'xGChain': '18.64459888264537',
#   'xGBuildup': '5.439551524817944'},
#  {'id': '2120',
#   'player_name': 'Gerard Moreno',
#   'games': '35',
#   'time': '2316',
#   'goals': '8',
#   'xG': '11.947289140895009',
#   'assists': '1',
#   'xA': '3.314938304014504',
#   'shots': '72',
#   'key_passes': '39',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Villarreal',
#   'npg': '8',
#   'npxG': '11.204011471942067',
#   'xGChain': '15.316588701680303',
#   'xGBuildup': '3.541935473680496'},
#  {'id': '2251',
#   'player_name': 'Gareth Bale',
#   'games': '29',
#   'time': '1786',
#   'goals': '8',
#   'xG': '9.418212609365582',
#   'assists': '3',
#   'xA': '3.250804353505373',
#   'shots': '76',
#   'key_passes': '18',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Madrid',
#   'npg': '7',
#   'npxG': '8.674935007467866',
#   'xGChain': '12.782862301915884',
#   'xGBuildup': '3.2878286903724074'},
#  {'id': '2381',
#   'player_name': 'Rodrigo',
#   'games': '33',
#   'time': '2538',
#   'goals': '8',
#   'xG': '14.69782342389226',
#   'assists': '6',
#   'xA': '4.1548741944134235',
#   'shots': '81',
#   'key_passes': '31',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Valencia',
#   'npg': '8',
#   'npxG': '13.954545754939318',
#   'xGChain': '24.716023348271847',
#   'xGBuildup': '8.055105708539486'},
#  {'id': '3226',
#   'player_name': 'Ousmane Dembélé',
#   'games': '29',
#   'time': '1673',
#   'goals': '8',
#   'xG': '4.283434369601309',
#   'assists': '5',
#   'xA': '5.402523474767804',
#   'shots': '39',
#   'key_passes': '45',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Barcelona',
#   'npg': '8',
#   'npxG': '4.283434369601309',
#   'xGChain': '11.178977493196726',
#   'xGBuildup': '3.907365268096328'},
#  {'id': '4136',
#   'player_name': 'Ángel',
#   'games': '37',
#   'time': '1816',
#   'goals': '8',
#   'xG': '8.297677567228675',
#   'assists': '3',
#   'xA': '4.1381445014849305',
#   'shots': '67',
#   'key_passes': '20',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Getafe',
#   'npg': '8',
#   'npxG': '8.297677567228675',
#   'xGChain': '11.206870198249817',
#   'xGBuildup': '0.6126872841268778'},
#  {'id': '2135',
#   'player_name': 'Sergi Enrich',
#   'games': '35',
#   'time': '2596',
#   'goals': '7',
#   'xG': '11.471798448823392',
#   'assists': '4',
#   'xA': '2.452523239888251',
#   'shots': '67',
#   'key_passes': '28',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Eibar',
#   'npg': '7',
#   'npxG': '11.471798448823392',
#   'xGChain': '15.442344807088375',
#   'xGBuildup': '3.991399483755231'},
#  {'id': '2384',
#   'player_name': 'Santi Mina',
#   'games': '30',
#   'time': '1866',
#   'goals': '7',
#   'xG': '8.34234125353396',
#   'assists': '5',
#   'xA': '4.067188637331128',
#   'shots': '43',
#   'key_passes': '16',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Valencia',
#   'npg': '7',
#   'npxG': '8.34234125353396',
#   'xGChain': '11.505678419955075',
#   'xGBuildup': '2.218737888149917'},
#  {'id': '2401',
#   'player_name': 'Muniain',
#   'games': '34',
#   'time': '2388',
#   'goals': '7',
#   'xG': '7.043154893442988',
#   'assists': '4',
#   'xA': '3.7107703760266304',
#   'shots': '25',
#   'key_passes': '29',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Athletic Club',
#   'npg': '6',
#   'npxG': '6.300133673474193',
#   'xGChain': '14.666821591556072',
#   'xGBuildup': '5.689677402377129'},
#  {'id': '2571',
#   'player_name': 'Sergio Canales',
#   'games': '32',
#   'time': '2660',
#   'goals': '7',
#   'xG': '7.552455742843449',
#   'assists': '2',
#   'xA': '5.525014239363372',
#   'shots': '66',
#   'key_passes': '56',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Betis',
#   'npg': '5',
#   'npxG': '6.065900479443371',
#   'xGChain': '13.07396335247904',
#   'xGBuildup': '5.755135937593877'},
#  {'id': '1125',
#   'player_name': 'Carlos Bacca',
#   'games': '33',
#   'time': '1250',
#   'goals': '6',
#   'xG': '3.953323293477297',
#   'assists': '1',
#   'xA': '1.8683365024626255',
#   'shots': '31',
#   'key_passes': '23',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Villarreal',
#   'npg': '5',
#   'npxG': '3.2100456841289997',
#   'xGChain': '5.059387130662799',
#   'xGBuildup': '1.240617785602808'},
#  {'id': '1804',
#   'player_name': 'Álvaro Morata',
#   'games': '15',
#   'time': '1094',
#   'goals': '6',
#   'xG': '7.418768474832177',
#   'assists': '1',
#   'xA': '0.617183530703187',
#   'shots': '30',
#   'key_passes': '5',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Atletico Madrid',
#   'npg': '6',
#   'npxG': '7.418768474832177',
#   'xGChain': '7.574720934033394',
#   'xGBuildup': '3.052136616781354'},
#  {'id': '2106',
#   'player_name': 'Munir',
#   'games': '23',
#   'time': '1198',
#   'goals': '6',
#   'xG': '6.675038103945553',
#   'assists': '2',
#   'xA': '1.3203009776771069',
#   'shots': '38',
#   'key_passes': '13',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Barcelona,Sevilla',
#   'npg': '6',
#   'npxG': '6.675038103945553',
#   'xGChain': '12.770650677382946',
#   'xGBuildup': '5.581458829343319'},
#  {'id': '2148',
#   'player_name': 'Joaquín',
#   'games': '30',
#   'time': '1688',
#   'goals': '6',
#   'xG': '4.244644002057612',
#   'assists': '0',
#   'xA': '3.8507550060749054',
#   'shots': '23',
#   'key_passes': '45',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Betis',
#   'npg': '6',
#   'npxG': '4.244644002057612',
#   'xGChain': '11.094103310257196',
#   'xGBuildup': '5.677002982236445'},
#  {'id': '2246',
#   'player_name': 'Sergio Ramos',
#   'games': '28',
#   'time': '2478',
#   'goals': '6',
#   'xG': '7.0838702339679',
#   'assists': '1',
#   'xA': '0.6119844429194927',
#   'shots': '31',
#   'key_passes': '8',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Real Madrid',
#   'npg': '1',
#   'npxG': '3.3677379470318556',
#   'xGChain': '9.920106902718544',
#   'xGBuildup': '8.61751701682806'},
#  {'id': '2442',
#   'player_name': 'Kevin Gameiro',
#   'games': '33',
#   'time': '1605',
#   'goals': '6',
#   'xG': '8.706866428256035',
#   'assists': '1',
#   'xA': '3.8101995903998613',
#   'shots': '36',
#   'key_passes': '26',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Valencia',
#   'npg': '6',
#   'npxG': '8.706866428256035',
#   'xGChain': '12.517383925616741',
#   'xGBuildup': '3.1089128889143467'},
#  {'id': '3424',
#   'player_name': 'Guido Carrillo',
#   'games': '32',
#   'time': '1996',
#   'goals': '6',
#   'xG': '9.66193257458508',
#   'assists': '1',
#   'xA': '1.4199218126013875',
#   'shots': '59',
#   'key_passes': '21',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Leganes',
#   'npg': '5',
#   'npxG': '7.432099724188447',
#   'xGChain': '10.047059167176485',
#   'xGBuildup': '4.327312270179391'},
#  {'id': '6219',
#   'player_name': 'Enes Ünal',
#   'games': '33',
#   'time': '2152',
#   'goals': '6',
#   'xG': '8.596426540985703',
#   'assists': '3',
#   'xA': '1.5610766867175698',
#   'shots': '53',
#   'key_passes': '19',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Valladolid',
#   'npg': '3',
#   'npxG': '6.366721587255597',
#   'xGChain': '8.194578994065523',
#   'xGBuildup': '1.6029752418398857'},
#  {'id': '6227',
#   'player_name': 'Brais Méndez',
#   'games': '31',
#   'time': '2358',
#   'goals': '6',
#   'xG': '5.761918738484383',
#   'assists': '7',
#   'xA': '4.472741516306996',
#   'shots': '70',
#   'key_passes': '45',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Celta Vigo',
#   'npg': '5',
#   'npxG': '5.018641117960215',
#   'xGChain': '10.954126724973321',
#   'xGBuildup': '4.573741470463574'},
#  {'id': '6528',
#   'player_name': 'Loren Morón',
#   'games': '33',
#   'time': '1953',
#   'goals': '6',
#   'xG': '9.439275989308953',
#   'assists': '0',
#   'xA': '1.7749988045543432',
#   'shots': '59',
#   'key_passes': '11',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Betis',
#   'npg': '6',
#   'npxG': '9.439275989308953',
#   'xGChain': '12.261407557874918',
#   'xGBuildup': '2.7812407137826085'},
#  {'id': '488',
#   'player_name': 'Philippe Coutinho',
#   'games': '34',
#   'time': '2026',
#   'goals': '5',
#   'xG': '7.843802811577916',
#   'assists': '2',
#   'xA': '4.11986799351871',
#   'shots': '69',
#   'key_passes': '31',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Barcelona',
#   'npg': '5',
#   'npxG': '7.843802811577916',
#   'xGChain': '21.019003113731742',
#   'xGBuildup': '11.806866269558668'},
#  {'id': '897',
#   'player_name': 'Juanmi',
#   'games': '30',
#   'time': '1517',
#   'goals': '5',
#   'xG': '6.072523904964328',
#   'assists': '2',
#   'xA': '1.5122700855135918',
#   'shots': '43',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Real Sociedad',
#   'npg': '5',
#   'npxG': '6.072523904964328',
#   'xGChain': '8.06476598419249',
#   'xGBuildup': '0.8729604594409466'},
#  {'id': '1701',
#   'player_name': 'Borja Bastón',
#   'games': '27',
#   'time': '1462',
#   'goals': '5',
#   'xG': '6.937000842764974',
#   'assists': '1',
#   'xA': '1.2777881026268005',
#   'shots': '33',
#   'key_passes': '8',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Alaves',
#   'npg': '5',
#   'npxG': '6.937000842764974',
#   'xGChain': '6.134073596447706',
#   'xGBuildup': '0.25884844549000263'},
#  {'id': '2166',
#   'player_name': 'Adrián Embarba',
#   'games': '36',
#   'time': '2294',
#   'goals': '5',
#   'xG': '6.649870955385268',
#   'assists': '6',
#   'xA': '5.809793941676617',
#   'shots': '49',
#   'key_passes': '53',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '2',
#   'npxG': '4.420683256350458',
#   'xGChain': '9.816613756120205',
#   'xGBuildup': '3.210052503272891'},
#  {'id': '2216',
#   'player_name': 'Jony',
#   'games': '36',
#   'time': '3010',
#   'goals': '5',
#   'xG': '4.312330758199096',
#   'assists': '10',
#   'xA': '9.690812710672617',
#   'shots': '54',
#   'key_passes': '87',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Alaves',
#   'npg': '5',
#   'npxG': '4.312330758199096',
#   'xGChain': '12.975019738078117',
#   'xGBuildup': '4.579494079574943'},
#  {'id': '5682',
#   'player_name': 'Gonçalo Guedes',
#   'games': '25',
#   'time': '1472',
#   'goals': '5',
#   'xG': '2.00748750846833',
#   'assists': '3',
#   'xA': '3.0421631895005703',
#   'shots': '35',
#   'key_passes': '21',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Valencia',
#   'npg': '5',
#   'npxG': '2.00748750846833',
#   'xGChain': '7.235342091880739',
#   'xGBuildup': '3.963828142732382'},
#  {'id': '7208',
#   'player_name': 'Samuel Chukwueze',
#   'games': '26',
#   'time': '1713',
#   'goals': '5',
#   'xG': '5.540321510285139',
#   'assists': '2',
#   'xA': '1.5905424021184444',
#   'shots': '58',
#   'key_passes': '22',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Villarreal',
#   'npg': '5',
#   'npxG': '5.540321510285139',
#   'xGChain': '9.830892715603113',
#   'xGBuildup': '3.398014657199383'},
#  {'id': '7349',
#   'player_name': 'Enric Gallego',
#   'games': '19',
#   'time': '1538',
#   'goals': '5',
#   'xG': '5.059456363320351',
#   'assists': '1',
#   'xA': '2.6912670228630304',
#   'shots': '32',
#   'key_passes': '15',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'SD Huesca',
#   'npg': '5',
#   'npxG': '5.059456363320351',
#   'xGChain': '7.846514970064163',
#   'xGBuildup': '2.235460123978555'},
#  {'id': '965',
#   'player_name': 'Santiago Cazorla',
#   'games': '35',
#   'time': '2651',
#   'goals': '4',
#   'xG': '4.290626532398164',
#   'assists': '10',
#   'xA': '7.843862919136882',
#   'shots': '31',
#   'key_passes': '72',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Villarreal',
#   'npg': '2',
#   'npxG': '2.0607937024906278',
#   'xGChain': '13.493425918743014',
#   'xGBuildup': '10.591213492676616'},
#  {'id': '1421',
#   'player_name': 'Cristian Tello',
#   'games': '29',
#   'time': '1547',
#   'goals': '4',
#   'xG': '3.137837682850659',
#   'assists': '6',
#   'xA': '4.465180344879627',
#   'shots': '36',
#   'key_passes': '28',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Betis',
#   'npg': '4',
#   'npxG': '3.137837682850659',
#   'xGChain': '11.799681842327118',
#   'xGBuildup': '5.511579358018935'},
#  {'id': '2073',
#   'player_name': 'Coke',
#   'games': '27',
#   'time': '1814',
#   'goals': '4',
#   'xG': '2.032701146788895',
#   'assists': '0',
#   'xA': '1.2979826536029577',
#   'shots': '12',
#   'key_passes': '12',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Levante',
#   'npg': '4',
#   'npxG': '2.032701146788895',
#   'xGChain': '5.305511684156954',
#   'xGBuildup': '4.195695878006518'},
#  {'id': '2079',
#   'player_name': 'Rubén Rochina',
#   'games': '27',
#   'time': '1823',
#   'goals': '4',
#   'xG': '2.1987620340660214',
#   'assists': '5',
#   'xA': '4.497421119362116',
#   'shots': '46',
#   'key_passes': '29',
#   'yellow_cards': '9',
#   'red_cards': '2',
#   'position': 'M S',
#   'team_title': 'Levante',
#   'npg': '4',
#   'npxG': '2.1987620340660214',
#   'xGChain': '8.110887029208243',
#   'xGBuildup': '5.130064584314823'},
#  {'id': '2092',
#   'player_name': 'Gerard Piqué',
#   'games': '35',
#   'time': '3150',
#   'goals': '4',
#   'xG': '4.12733706086874',
#   'assists': '2',
#   'xA': '1.386895578354597',
#   'shots': '18',
#   'key_passes': '6',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Barcelona',
#   'npg': '4',
#   'npxG': '4.12733706086874',
#   'xGChain': '14.633865851908922',
#   'xGBuildup': '13.671035397797823'},
#  {'id': '2122',
#   'player_name': 'Joan Jordán',
#   'games': '36',
#   'time': '2884',
#   'goals': '4',
#   'xG': '2.6048226170241833',
#   'assists': '4',
#   'xA': '4.202819157391787',
#   'shots': '58',
#   'key_passes': '66',
#   'yellow_cards': '10',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Eibar',
#   'npg': '4',
#   'npxG': '2.6048226170241833',
#   'xGChain': '11.686160681769252',
#   'xGBuildup': '8.812397222034633'},
#  {'id': '2266',
#   'player_name': 'Saúl Ñíguez',
#   'games': '33',
#   'time': '2923',
#   'goals': '4',
#   'xG': '5.614009996876121',
#   'assists': '1',
#   'xA': '1.6522030681371689',
#   'shots': '51',
#   'key_passes': '15',
#   'yellow_cards': '10',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '4',
#   'npxG': '4.8707323875278234',
#   'xGChain': '9.59379474632442',
#   'xGBuildup': '6.301001405343413'},
#  {'id': '2357',
#   'player_name': 'Nabil El Zhar',
#   'games': '27',
#   'time': '945',
#   'goals': '4',
#   'xG': '2.7727257208898664',
#   'assists': '0',
#   'xA': '0.6738703921437263',
#   'shots': '26',
#   'key_passes': '17',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leganes',
#   'npg': '3',
#   'npxG': '2.0294481115415692',
#   'xGChain': '3.313385719433427',
#   'xGBuildup': '0.9537858795374632'},
#  {'id': '2394',
#   'player_name': 'Etxeita',
#   'games': '31',
#   'time': '2678',
#   'goals': '4',
#   'xG': '3.3156366422772408',
#   'assists': '0',
#   'xA': '0.5936140157282352',
#   'shots': '24',
#   'key_passes': '4',
#   'yellow_cards': '11',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'SD Huesca',
#   'npg': '4',
#   'npxG': '3.3156366422772408',
#   'xGChain': '3.826202543452382',
#   'xGBuildup': '2.9305997397750616'},
#  {'id': '2437',
#   'player_name': 'Gonzalo Escalante',
#   'games': '32',
#   'time': '1779',
#   'goals': '4',
#   'xG': '3.8881872184574604',
#   'assists': '1',
#   'xA': '1.0066494345664978',
#   'shots': '21',
#   'key_passes': '9',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Eibar',
#   'npg': '4',
#   'npxG': '3.8881872184574604',
#   'xGChain': '8.201344955712557',
#   'xGBuildup': '5.088594676926732'},
#  {'id': '2621',
#   'player_name': 'Sergi Darder',
#   'games': '34',
#   'time': '2730',
#   'goals': '4',
#   'xG': '3.290027947165072',
#   'assists': '2',
#   'xA': '3.756815630942583',
#   'shots': '55',
#   'key_passes': '37',
#   'yellow_cards': '6',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Espanyol',
#   'npg': '4',
#   'npxG': '3.290027947165072',
#   'xGChain': '10.297068750485778',
#   'xGBuildup': '4.499734027311206'},
#  {'id': '3211',
#   'player_name': 'Martin Braithwaite',
#   'games': '19',
#   'time': '1414',
#   'goals': '4',
#   'xG': '5.37516138330102',
#   'assists': '5',
#   'xA': '1.7639280296862125',
#   'shots': '29',
#   'key_passes': '15',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Leganes',
#   'npg': '4',
#   'npxG': '5.37516138330102',
#   'xGChain': '6.625636886805296',
#   'xGBuildup': '0.627817302942276'},
#  {'id': '6570',
#   'player_name': 'Óscar Rodríguez',
#   'games': '31',
#   'time': '2524',
#   'goals': '4',
#   'xG': '3.9236903339624405',
#   'assists': '3',
#   'xA': '5.054329359903932',
#   'shots': '61',
#   'key_passes': '48',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leganes',
#   'npg': '4',
#   'npxG': '3.9236903339624405',
#   'xGChain': '8.35155005659908',
#   'xGBuildup': '3.0398232601583004'},
#  {'id': '6951',
#   'player_name': 'Álex Gallar',
#   'games': '25',
#   'time': '996',
#   'goals': '4',
#   'xG': '3.62275168672204',
#   'assists': '1',
#   'xA': '2.256336599588394',
#   'shots': '27',
#   'key_passes': '28',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'SD Huesca',
#   'npg': '3',
#   'npxG': '2.879474077373743',
#   'xGChain': '5.3794100526720285',
#   'xGBuildup': '1.124302539974451'},
#  {'id': '6954',
#   'player_name': 'Juan Camilo Hernández',
#   'games': '34',
#   'time': '2171',
#   'goals': '4',
#   'xG': '10.610809810459614',
#   'assists': '3',
#   'xA': '4.564482043962926',
#   'shots': '80',
#   'key_passes': '33',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'SD Huesca',
#   'npg': '2',
#   'npxG': '9.124639935791492',
#   'xGChain': '14.462969301268458',
#   'xGBuildup': '2.67464404925704'},
#  {'id': '7071',
#   'player_name': 'Álvaro García',
#   'games': '35',
#   'time': '1750',
#   'goals': '4',
#   'xG': '4.425083102658391',
#   'assists': '2',
#   'xA': '2.9116673562675714',
#   'shots': '27',
#   'key_passes': '20',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '4',
#   'npxG': '4.425083102658391',
#   'xGChain': '9.902181381359696',
#   'xGBuildup': '3.3773929215967655'},
#  {'id': '222',
#   'player_name': 'Arturo Vidal',
#   'games': '33',
#   'time': '1935',
#   'goals': '3',
#   'xG': '3.7394639533013105',
#   'assists': '7',
#   'xA': '5.37700461409986',
#   'shots': '24',
#   'key_passes': '22',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Barcelona',
#   'npg': '3',
#   'npxG': '3.7394639533013105',
#   'xGChain': '16.929492242634296',
#   'xGBuildup': '9.690826129168272'},
#  {'id': '1520',
#   'player_name': 'Éver Banega',
#   'games': '32',
#   'time': '2699',
#   'goals': '3',
#   'xG': '2.8135862164199352',
#   'assists': '4',
#   'xA': '3.9505247082561255',
#   'shots': '32',
#   'key_passes': '53',
#   'yellow_cards': '15',
#   'red_cards': '2',
#   'position': 'M',
#   'team_title': 'Sevilla',
#   'npg': '1',
#   'npxG': '1.3270309139043093',
#   'xGChain': '17.80649769306183',
#   'xGBuildup': '15.572122730314732'},
#  {'id': '1734',
#   'player_name': 'Sofiane Boufal',
#   'games': '35',
#   'time': '2114',
#   'goals': '3',
#   'xG': '3.51104224473238',
#   'assists': '3',
#   'xA': '3.6261964542791247',
#   'shots': '51',
#   'key_passes': '40',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Celta Vigo',
#   'npg': '3',
#   'npxG': '3.51104224473238',
#   'xGChain': '9.149213660508394',
#   'xGBuildup': '3.410238904878497'},
#  {'id': '1836',
#   'player_name': 'Franco Vázquez',
#   'games': '34',
#   'time': '2298',
#   'goals': '3',
#   'xG': '4.320327654480934',
#   'assists': '4',
#   'xA': '4.719091894105077',
#   'shots': '45',
#   'key_passes': '30',
#   'yellow_cards': '8',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Sevilla',
#   'npg': '3',
#   'npxG': '4.320327654480934',
#   'xGChain': '16.875291088595986',
#   'xGBuildup': '10.39325425028801'},
#  {'id': '2065',
#   'player_name': 'Vicente Iborra',
#   'games': '19',
#   'time': '1671',
#   'goals': '3',
#   'xG': '2.2688943478278816',
#   'assists': '1',
#   'xA': '0.8494713800027966',
#   'shots': '18',
#   'key_passes': '7',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Villarreal',
#   'npg': '3',
#   'npxG': '2.2688943478278816',
#   'xGChain': '6.400822818279266',
#   'xGBuildup': '4.577450141310692'},
#  {'id': '2094',
#   'player_name': 'Ivan Rakitic',
#   'games': '34',
#   'time': '2641',
#   'goals': '3',
#   'xG': '2.6884999126195908',
#   'assists': '5',
#   'xA': '1.9144196547567844',
#   'shots': '36',
#   'key_passes': '16',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Barcelona',
#   'npg': '3',
#   'npxG': '2.6884999126195908',
#   'xGChain': '21.14412023127079',
#   'xGBuildup': '18.074898958206177'},
#  {'id': '2196',
#   'player_name': 'Álvaro Medrán',
#   'games': '21',
#   'time': '1145',
#   'goals': '3',
#   'xG': '2.411801014095545',
#   'assists': '0',
#   'xA': '1.091577854938805',
#   'shots': '24',
#   'key_passes': '29',
#   'yellow_cards': '6',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '3',
#   'npxG': '2.411801014095545',
#   'xGChain': '6.277203223668039',
#   'xGBuildup': '3.875898103695363'},
#  {'id': '2240',
#   'player_name': 'Esteban Granero',
#   'games': '28',
#   'time': '2036',
#   'goals': '3',
#   'xG': '1.9888052525930107',
#   'assists': '1',
#   'xA': '1.337591121904552',
#   'shots': '30',
#   'key_passes': '27',
#   'yellow_cards': '11',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Espanyol',
#   'npg': '3',
#   'npxG': '1.9888052525930107',
#   'xGChain': '7.205379223451018',
#   'xGBuildup': '6.168979624286294'},
#  {'id': '2248',
#   'player_name': 'Casemiro',
#   'games': '29',
#   'time': '2317',
#   'goals': '3',
#   'xG': '1.6635238844901323',
#   'assists': '0',
#   'xA': '1.1146268006414175',
#   'shots': '40',
#   'key_passes': '14',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '1.6635238844901323',
#   'xGChain': '9.677065351977944',
#   'xGBuildup': '8.754740625619888'},
#  {'id': '2250',
#   'player_name': 'Luka Modric',
#   'games': '34',
#   'time': '2628',
#   'goals': '3',
#   'xG': '2.941043745726347',
#   'assists': '6',
#   'xA': '3.724833169952035',
#   'shots': '37',
#   'key_passes': '54',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '2.941043745726347',
#   'xGChain': '15.293119676411152',
#   'xGBuildup': '11.321296686306596'},
#  {'id': '2252',
#   'player_name': 'Borja Mayoral',
#   'games': '29',
#   'time': '1602',
#   'goals': '3',
#   'xG': '4.703446423634887',
#   'assists': '2',
#   'xA': '3.2847628872841597',
#   'shots': '24',
#   'key_passes': '20',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Levante',
#   'npg': '3',
#   'npxG': '4.703446423634887',
#   'xGChain': '8.915443209931254',
#   'xGBuildup': '2.6578833740204573'},
#  {'id': '2255',
#   'player_name': 'Isco',
#   'games': '27',
#   'time': '1186',
#   'goals': '3',
#   'xG': '5.304060861468315',
#   'assists': '2',
#   'xA': '2.2470094049349427',
#   'shots': '25',
#   'key_passes': '26',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '5.304060861468315',
#   'xGChain': '11.303339049220085',
#   'xGBuildup': '5.035098061896861'},
#  {'id': '2264',
#   'player_name': 'Diego Godín',
#   'games': '30',
#   'time': '2507',
#   'goals': '3',
#   'xG': '3.2220259942114353',
#   'assists': '1',
#   'xA': '0.5228416891768575',
#   'shots': '14',
#   'key_passes': '3',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '3.2220259942114353',
#   'xGChain': '6.832797525450587',
#   'xGBuildup': '6.266717946156859'},
#  {'id': '2269',
#   'player_name': 'Koke',
#   'games': '30',
#   'time': '2586',
#   'goals': '3',
#   'xG': '1.4969831500202417',
#   'assists': '4',
#   'xA': '5.000096630305052',
#   'shots': '21',
#   'key_passes': '61',
#   'yellow_cards': '8',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '1.4969831500202417',
#   'xGChain': '14.48270177654922',
#   'xGBuildup': '11.494231699034572'},
#  {'id': '2275',
#   'player_name': 'Ángel Correa',
#   'games': '36',
#   'time': '1922',
#   'goals': '3',
#   'xG': '2.3123123794794083',
#   'assists': '2',
#   'xA': '5.113178012892604',
#   'shots': '32',
#   'key_passes': '38',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '2.3123123794794083',
#   'xGChain': '8.524402521550655',
#   'xGBuildup': '3.4207815937697887'},
#  {'id': '2285',
#   'player_name': 'Fabián Orellana',
#   'games': '33',
#   'time': '2748',
#   'goals': '3',
#   'xG': '7.043204225599766',
#   'assists': '5',
#   'xA': '5.558927631005645',
#   'shots': '78',
#   'key_passes': '48',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Eibar',
#   'npg': '2',
#   'npxG': '6.299926586449146',
#   'xGChain': '15.170350555330515',
#   'xGBuildup': '5.7352637611329556'},
#  {'id': '2328',
#   'player_name': 'Thomas Partey',
#   'games': '32',
#   'time': '2071',
#   'goals': '3',
#   'xG': '1.6186930015683174',
#   'assists': '4',
#   'xA': '1.0440308079123497',
#   'shots': '36',
#   'key_passes': '20',
#   'yellow_cards': '7',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '1.6186930015683174',
#   'xGChain': '8.585972351953387',
#   'xGBuildup': '7.028006281703711'},
#  {'id': '2331',
#   'player_name': 'Roberto Rosales',
#   'games': '21',
#   'time': '1750',
#   'goals': '3',
#   'xG': '0.8256827862933278',
#   'assists': '1',
#   'xA': '1.2024134527891874',
#   'shots': '19',
#   'key_passes': '12',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Espanyol',
#   'npg': '3',
#   'npxG': '0.8256827862933278',
#   'xGChain': '6.853435875847936',
#   'xGBuildup': '5.6644277442246675'},
#  {'id': '2446',
#   'player_name': 'Dani Ceballos',
#   'games': '23',
#   'time': '1245',
#   'goals': '3',
#   'xG': '2.237287884578109',
#   'assists': '0',
#   'xA': '1.2545571215450764',
#   'shots': '22',
#   'key_passes': '24',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '2.237287884578109',
#   'xGChain': '8.683115845546126',
#   'xGBuildup': '6.015689268708229'},
#  {'id': '2491',
#   'player_name': 'Ibai Gómez',
#   'games': '32',
#   'time': '2045',
#   'goals': '3',
#   'xG': '3.817070795223117',
#   'assists': '4',
#   'xA': '2.800104613415897',
#   'shots': '51',
#   'key_passes': '36',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Alaves,Athletic Club',
#   'npg': '3',
#   'npxG': '3.0737931709736586',
#   'xGChain': '6.229776987805963',
#   'xGBuildup': '2.449585370719433'},
#  {'id': '2496',
#   'player_name': 'Rodri',
#   'games': '34',
#   'time': '2750',
#   'goals': '3',
#   'xG': '2.8055384308099747',
#   'assists': '1',
#   'xA': '1.4767019730061293',
#   'shots': '27',
#   'key_passes': '17',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Atletico Madrid',
#   'npg': '3',
#   'npxG': '2.8055384308099747',
#   'xGChain': '11.48037722799927',
#   'xGBuildup': '10.115192200057209'},
#  {'id': '2509',
#   'player_name': 'Dimitri Foulquier',
#   'games': '25',
#   'time': '1816',
#   'goals': '3',
#   'xG': '1.450738564133644',
#   'assists': '2',
#   'xA': '1.67509126663208',
#   'shots': '13',
#   'key_passes': '15',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Getafe',
#   'npg': '3',
#   'npxG': '1.450738564133644',
#   'xGChain': '3.8102706726640463',
#   'xGBuildup': '1.4761596228927374'},
#  {'id': '2521',
#   'player_name': 'Alfonso',
#   'games': '34',
#   'time': '2083',
#   'goals': '3',
#   'xG': '3.5729416236281395',
#   'assists': '3',
#   'xA': '4.023802416399121',
#   'shots': '36',
#   'key_passes': '25',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Villarreal',
#   'npg': '3',
#   'npxG': '3.5729416236281395',
#   'xGChain': '11.525455437600613',
#   'xGBuildup': '5.945527506992221'},
#  {'id': '4034',
#   'player_name': 'José Campaña',
#   'games': '36',
#   'time': '3216',
#   'goals': '3',
#   'xG': '1.8639116622507572',
#   'assists': '9',
#   'xA': '6.4570074789226055',
#   'shots': '20',
#   'key_passes': '58',
#   'yellow_cards': '12',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Levante',
#   'npg': '3',
#   'npxG': '1.8639116622507572',
#   'xGChain': '11.875046184286475',
#   'xGBuildup': '8.867600198835135'},
#  {'id': '4485',
#   'player_name': 'José Pozo',
#   'games': '29',
#   'time': '1613',
#   'goals': '3',
#   'xG': '3.1025851164013147',
#   'assists': '0',
#   'xA': '1.6310933148488402',
#   'shots': '22',
#   'key_passes': '30',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Rayo Vallecano',
#   'npg': '3',
#   'npxG': '3.1025851164013147',
#   'xGChain': '8.859109994024038',
#   'xGBuildup': '5.137124687433243'},
#  {'id': '5047',
#   'player_name': 'Rubén Sobrino',
#   'games': '24',
#   'time': '1144',
#   'goals': '3',
#   'xG': '2.540001843124628',
#   'assists': '1',
#   'xA': '1.2649947386234999',
#   'shots': '23',
#   'key_passes': '10',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Alaves,Valencia',
#   'npg': '3',
#   'npxG': '2.540001843124628',
#   'xGChain': '4.185793932527304',
#   'xGBuildup': '0.7109360359609127'},
#  {'id': '5074',
#   'player_name': 'Kike García',
#   'games': '30',
#   'time': '1291',
#   'goals': '3',
#   'xG': '5.795347250066698',
#   'assists': '0',
#   'xA': '1.7424581125378609',
#   'shots': '43',
#   'key_passes': '14',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Eibar',
#   'npg': '3',
#   'npxG': '5.795347250066698',
#   'xGChain': '9.687257844954729',
#   'xGBuildup': '2.962299693375826'},
#  {'id': '5110',
#   'player_name': 'Mariano',
#   'games': '13',
#   'time': '428',
#   'goals': '3',
#   'xG': '2.8303465098142624',
#   'assists': '0',
#   'xA': '0.9219048246741295',
#   'shots': '23',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Real Madrid',
#   'npg': '3',
#   'npxG': '2.8303465098142624',
#   'xGChain': '3.2826745565980673',
#   'xGBuildup': '0.14356526359915733'},
#  {'id': '5159',
#   'player_name': 'Marc Cardona',
#   'games': '17',
#   'time': '600',
#   'goals': '3',
#   'xG': '3.202003860846162',
#   'assists': '1',
#   'xA': '0.6709005311131477',
#   'shots': '17',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Eibar',
#   'npg': '3',
#   'npxG': '3.202003860846162',
#   'xGChain': '4.598438395187259',
#   'xGBuildup': '0.951893137767911'},
#  {'id': '5212',
#   'player_name': 'Sergi Guardiola',
#   'games': '20',
#   'time': '1541',
#   'goals': '3',
#   'xG': '5.544554196298122',
#   'assists': '1',
#   'xA': '2.0693446192890406',
#   'shots': '48',
#   'key_passes': '9',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Getafe,Real Valladolid',
#   'npg': '3',
#   'npxG': '4.801276572048664',
#   'xGChain': '6.551284126937389',
#   'xGBuildup': '0.3906827289611101'},
#  {'id': '5304',
#   'player_name': 'Mikel Merino',
#   'games': '29',
#   'time': '2058',
#   'goals': '3',
#   'xG': '2.7844471940770745',
#   'assists': '3',
#   'xA': '2.0293741384521127',
#   'shots': '24',
#   'key_passes': '15',
#   'yellow_cards': '8',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Real Sociedad',
#   'npg': '3',
#   'npxG': '2.7844471940770745',
#   'xGChain': '9.160567797720432',
#   'xGBuildup': '5.814551139250398'},
#  {'id': '6136',
#   'player_name': 'Mario Hermoso',
#   'games': '32',
#   'time': '2806',
#   'goals': '3',
#   'xG': '3.4728834605775774',
#   'assists': '0',
#   'xA': '0.18107372522354126',
#   'shots': '27',
#   'key_passes': '4',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Espanyol',
#   'npg': '3',
#   'npxG': '3.4728834605775774',
#   'xGChain': '5.778676187619567',
#   'xGBuildup': '5.470440208911896'},
#  {'id': '6217',
#   'player_name': 'Enis Bardhi',
#   'games': '36',
#   'time': '2840',
#   'goals': '3',
#   'xG': '3.911807905882597',
#   'assists': '4',
#   'xA': '3.5243095252662897',
#   'shots': '66',
#   'key_passes': '29',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Levante',
#   'npg': '3',
#   'npxG': '3.911807905882597',
#   'xGChain': '11.77427508495748',
#   'xGBuildup': '7.758485862985253'},
#  {'id': '6485',
#   'player_name': 'Júnior Firpo',
#   'games': '24',
#   'time': '1937',
#   'goals': '3',
#   'xG': '2.806339723058045',
#   'assists': '4',
#   'xA': '2.6039574332535267',
#   'shots': '19',
#   'key_passes': '20',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Real Betis',
#   'npg': '3',
#   'npxG': '2.806339723058045',
#   'xGChain': '6.52999802865088',
#   'xGBuildup': '3.928142821416259'},
#  {'id': '6567',
#   'player_name': 'Jonathan Silva',
#   'games': '30',
#   'time': '2700',
#   'goals': '3',
#   'xG': '1.9934130012989044',
#   'assists': '6',
#   'xA': '5.396804401651025',
#   'shots': '23',
#   'key_passes': '47',
#   'yellow_cards': '9',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Leganes',
#   'npg': '3',
#   'npxG': '1.9934130012989044',
#   'xGChain': '8.673488820903003',
#   'xGBuildup': '3.9688031719997525'},
#  {'id': '6917',
#   'player_name': 'Rubén Alcaraz',
#   'games': '34',
#   'time': '2979',
#   'goals': '3',
#   'xG': '3.7584781758487225',
#   'assists': '2',
#   'xA': '0.9931122791022062',
#   'shots': '52',
#   'key_passes': '21',
#   'yellow_cards': '13',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Real Valladolid',
#   'npg': '3',
#   'npxG': '3.0152005665004253',
#   'xGChain': '9.273644377477467',
#   'xGBuildup': '7.906211735680699'},
#  {'id': '6921',
#   'player_name': 'Óscar Plano',
#   'games': '33',
#   'time': '2699',
#   'goals': '3',
#   'xG': '4.245734766125679',
#   'assists': '4',
#   'xA': '3.4868918415158987',
#   'shots': '46',
#   'key_passes': '30',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Valladolid',
#   'npg': '3',
#   'npxG': '4.245734766125679',
#   'xGChain': '10.412579007446766',
#   'xGBuildup': '4.439914869144559'},
#  {'id': '6930',
#   'player_name': 'Néstor Araújo',
#   'games': '32',
#   'time': '2682',
#   'goals': '3',
#   'xG': '1.0623298436403275',
#   'assists': '0',
#   'xA': '0.6184253674000502',
#   'shots': '12',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Celta Vigo',
#   'npg': '3',
#   'npxG': '1.0623298436403275',
#   'xGChain': '5.7377930879592896',
#   'xGBuildup': '5.575500920414925'},
#  {'id': '6950',
#   'player_name': 'Jorge Pulido',
#   'games': '32',
#   'time': '2796',
#   'goals': '3',
#   'xG': '2.654288798570633',
#   'assists': '3',
#   'xA': '0.8361032400280237',
#   'shots': '19',
#   'key_passes': '13',
#   'yellow_cards': '9',
#   'red_cards': '2',
#   'position': 'D',
#   'team_title': 'SD Huesca',
#   'npg': '3',
#   'npxG': '2.654288798570633',
#   'xGChain': '3.714838108047843',
#   'xGBuildup': '3.0358233246952295'},
#  {'id': '7398',
#   'player_name': 'Wu Lei',
#   'games': '16',
#   'time': '1078',
#   'goals': '3',
#   'xG': '4.580128565430641',
#   'assists': '1',
#   'xA': '1.4147594217211008',
#   'shots': '30',
#   'key_passes': '10',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Espanyol',
#   'npg': '3',
#   'npxG': '4.580128565430641',
#   'xGChain': '6.711037321016192',
#   'xGBuildup': '1.5254940539598465'},
#  {'id': '44',
#   'player_name': 'Pablo De Blasis',
#   'games': '24',
#   'time': '1520',
#   'goals': '2',
#   'xG': '1.072720630094409',
#   'assists': '0',
#   'xA': '2.069857321679592',
#   'shots': '12',
#   'key_passes': '23',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'D M S',
#   'team_title': 'Eibar',
#   'npg': '2',
#   'npxG': '1.072720630094409',
#   'xGChain': '4.993368562310934',
#   'xGBuildup': '2.5767414681613445'},
#  {'id': '452',
#   'player_name': 'Takashi Inui',
#   'games': '20',
#   'time': '1221',
#   'goals': '2',
# ...
#   'assists': '0',
#   'xA': '0.09144227206707001',
#   'shots': '4',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Celta Vigo',
#   'npg': '0',
#   'npxG': '0.13764986209571362',
#   'xGChain': '0.7812974192202091',
#   'xGBuildup': '0.5986627079546452'},
#  {'id': '7169',
#   'player_name': 'Moses Simon',
#   'games': '19',
#   'time': '774',
#   'goals': '0',
#   'xG': '1.392779940739274',
#   'assists': '1',
#   'xA': '0.7579310387372971',
#   'shots': '15',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Levante',
#   'npg': '0',
#   'npxG': '1.392779940739274',
#   'xGChain': '2.882112892344594',
#   'xGBuildup': '0.8820991367101669'},
#  {'id': '7182',
#   'player_name': 'Moisés Delgado',
#   'games': '3',
#   'time': '270',
#   'goals': '0',
#   'xG': '0.030662632081657648',
#   'assists': '0',
#   'xA': '0.07561113685369492',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0.030662632081657648',
#   'xGChain': '0.8129235357046127',
#   'xGBuildup': '0.7202108204364777'},
#  {'id': '7187',
#   'player_name': 'Sergio Reguilón',
#   'games': '14',
#   'time': '1122',
#   'goals': '0',
#   'xG': '0.2756411246955395',
#   'assists': '2',
#   'xA': '1.9488633964210749',
#   'shots': '6',
#   'key_passes': '17',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Real Madrid',
#   'npg': '0',
#   'npxG': '0.2756411246955395',
#   'xGChain': '4.71876548230648',
#   'xGBuildup': '4.158243000507355'},
#  {'id': '7188',
#   'player_name': 'Aleksandar Jovanovic',
#   'games': '12',
#   'time': '1080',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'SD Huesca',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.21952457167208195',
#   'xGBuildup': '0.21952457167208195'},
#  {'id': '7194',
#   'player_name': 'Andriy Lunin',
#   'games': '5',
#   'time': '364',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK S',
#   'team_title': 'Leganes',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.03140901029109955',
#   'xGBuildup': '0.03140901029109955'},
#  {'id': '7195',
#   'player_name': 'Roberto López',
#   'games': '1',
#   'time': '27',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7245',
#   'player_name': 'Javi Sánchez',
#   'games': '1',
#   'time': '45',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Madrid',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7246',
#   'player_name': 'Valery Fernández',
#   'games': '17',
#   'time': '888',
#   'goals': '0',
#   'xG': '0.07374600134789944',
#   'assists': '1',
#   'xA': '0.7988069728016853',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Girona',
#   'npg': '0',
#   'npxG': '0.07374600134789944',
#   'xGChain': '2.572099832817912',
#   'xGBuildup': '1.7427977472543716'},
#  {'id': '7258',
#   'player_name': 'Joaquín Muñoz',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Atletico Madrid',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7271',
#   'player_name': 'Fran Manzanara',
#   'games': '4',
#   'time': '153',
#   'goals': '0',
#   'xG': '0.09938467293977737',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Levante',
#   'npg': '0',
#   'npxG': '0.09938467293977737',
#   'xGChain': '0.16068264469504356',
#   'xGBuildup': '0.16068264469504356'},
#  {'id': '7274',
#   'player_name': 'Cristian Ganea',
#   'games': '1',
#   'time': '53',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Athletic Club',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.4754590094089508',
#   'xGBuildup': '0.4754590094089508'},
#  {'id': '7276',
#   'player_name': 'Robin Le Normand',
#   'games': '4',
#   'time': '283',
#   'goals': '0',
#   'xG': '0.0681137666106224',
#   'assists': '1',
#   'xA': '0.7805836796760559',
#   'shots': '2',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0.0681137666106224',
#   'xGChain': '0.6131800562143326',
#   'xGBuildup': '0.5961017273366451'},
#  {'id': '7303',
#   'player_name': 'Camacho',
#   'games': '3',
#   'time': '31',
#   'goals': '0',
#   'xG': '0.12458847463130951',
#   'assists': '0',
#   'xA': '0.19009611755609512',
#   'shots': '3',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'SD Huesca',
#   'npg': '0',
#   'npxG': '0.12458847463130951',
#   'xGChain': '0.1961282417178154',
#   'xGBuildup': '0'},
#  {'id': '7306',
#   'player_name': 'Aihen Muñoz',
#   'games': '11',
#   'time': '955',
#   'goals': '0',
#   'xG': '0.11700574308633804',
#   'assists': '0',
#   'xA': '0.23862803867086768',
#   'shots': '2',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0.11700574308633804',
#   'xGChain': '1.5569721180945635',
#   'xGBuildup': '1.345617157407105'},
#  {'id': '7313',
#   'player_name': 'Lee Kang-In',
#   'games': '3',
#   'time': '15',
#   'goals': '0',
#   'xG': '0.018162697553634644',
#   'assists': '0',
#   'xA': '0.1015261858701706',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Valencia',
#   'npg': '0',
#   'npxG': '0.018162697553634644',
#   'xGChain': '0.08978327363729477',
#   'xGBuildup': '0.08978327363729477'},
#  {'id': '7343',
#   'player_name': 'Cristo González',
#   'games': '1',
#   'time': '43',
#   'goals': '0',
#   'xG': '0.049706507474184036',
#   'assists': '0',
#   'xA': '0.04465055838227272',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Madrid',
#   'npg': '0',
#   'npxG': '0.049706507474184036',
#   'xGChain': '0.09435706585645676',
#   'xGBuildup': '0.04465055838227272'},
#  {'id': '7350',
#   'player_name': 'Yangel Herrera',
#   'games': '16',
#   'time': '1166',
#   'goals': '0',
#   'xG': '0.46410399954766035',
#   'assists': '0',
#   'xA': '0.08919779397547245',
#   'shots': '14',
#   'key_passes': '3',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'SD Huesca',
#   'npg': '0',
#   'npxG': '0.46410399954766035',
#   'xGChain': '2.1544727124273777',
#   'xGBuildup': '1.7387807685881853'},
#  {'id': '7351',
#   'player_name': 'Victor Mollejo',
#   'games': '4',
#   'time': '59',
#   'goals': '0',
#   'xG': '0.11602514050900936',
#   'assists': '0',
#   'xA': '0.019616231322288513',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Atletico Madrid',
#   'npg': '0',
#   'npxG': '0.11602514050900936',
#   'xGChain': '0.17567914724349976',
#   'xGBuildup': '0.04003777727484703'},
#  {'id': '7354',
#   'player_name': 'Diego Lainez',
#   'games': '12',
#   'time': '347',
#   'goals': '0',
#   'xG': '0.2950246389955282',
#   'assists': '1',
#   'xA': '0.3393640536814928',
#   'shots': '10',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Real Betis',
#   'npg': '0',
#   'npxG': '0.2950246389955282',
#   'xGChain': '1.2804789133369923',
#   'xGBuildup': '0.8015166632831097'},
#  {'id': '7364',
#   'player_name': 'Vasyl Kravets',
#   'games': '6',
#   'time': '487',
#   'goals': '0',
#   'xG': '0.1420431062579155',
#   'assists': '0',
#   'xA': '0.9126528054475784',
#   'shots': '4',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Leganes',
#   'npg': '0',
#   'npxG': '0.1420431062579155',
#   'xGChain': '1.3165626432746649',
#   'xGBuildup': '1.1340375859290361'},
#  {'id': '7366',
#   'player_name': 'Maximilian Wöber',
#   'games': '7',
#   'time': '535',
#   'goals': '0',
#   'xG': '0.19579791650176048',
#   'assists': '0',
#   'xA': '0.5373725276440382',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Sevilla',
#   'npg': '0',
#   'npxG': '0.19579791650176048',
#   'xGChain': '2.253508284687996',
#   'xGBuildup': '1.778277225792408'},
#  {'id': '7368',
#   'player_name': 'Emmanuel Apeh',
#   'games': '2',
#   'time': '11',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.05286291986703873',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Celta Vigo',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.05286291986703873',
#   'xGBuildup': '0'},
#  {'id': '7385',
#   'player_name': 'Javi Galán',
#   'games': '16',
#   'time': '1440',
#   'goals': '0',
#   'xG': '0.07497730012983084',
#   'assists': '2',
#   'xA': '2.257701708935201',
#   'shots': '2',
#   'key_passes': '18',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'SD Huesca',
#   'npg': '0',
#   'npxG': '0.07497730012983084',
#   'xGChain': '3.5428891396149993',
#   'xGBuildup': '1.4771055895835161'},
#  {'id': '7402',
#   'player_name': 'Álex Blanco',
#   'games': '2',
#   'time': '14',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Alaves',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7409',
#   'player_name': 'Alfa Semedo',
#   'games': '3',
#   'time': '40',
#   'goals': '0',
#   'xG': '0.0326814129948616',
#   'assists': '0',
#   'xA': '0.018779801204800606',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Espanyol',
#   'npg': '0',
#   'npxG': '0.0326814129948616',
#   'xGChain': '0.07044040225446224',
#   'xGBuildup': '0.028773240745067596'},
#  {'id': '7424',
#   'player_name': 'Alex Sola',
#   'games': '1',
#   'time': '90',
#   'goals': '0',
#   'xG': '0.0790611058473587',
#   'assists': '0',
#   'xA': '0.10102477669715881',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0.0790611058473587',
#   'xGChain': '0.8253956437110901',
#   'xGBuildup': '0.6580272316932678'},
#  {'id': '7426',
#   'player_name': 'Stiven Plaza',
#   'games': '2',
#   'time': '34',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Valladolid',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7430',
#   'player_name': 'Emerson',
#   'games': '6',
#   'time': '319',
#   'goals': '0',
#   'xG': '0.14468136429786682',
#   'assists': '0',
#   'xA': '0.27378785610198975',
#   'shots': '3',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Real Betis',
#   'npg': '0',
#   'npxG': '0.14468136429786682',
#   'xGChain': '0.8765059746801853',
#   'xGBuildup': '0.4984954185783863'},
#  {'id': '7492',
#   'player_name': 'Xavier Quintillá',
#   'games': '7',
#   'time': '628',
#   'goals': '0',
#   'xG': '0.09483938664197922',
#   'assists': '0',
#   'xA': '0.37356826290488243',
#   'shots': '3',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Villarreal',
#   'npg': '0',
#   'npxG': '0.09483938664197922',
#   'xGChain': '0.9015613794326782',
#   'xGBuildup': '0.6192917767912149'},
#  {'id': '7514',
#   'player_name': 'Lucas Olaza',
#   'games': '10',
#   'time': '898',
#   'goals': '0',
#   'xG': '0',
#   'assists': '2',
#   'xA': '0.5657829325646162',
#   'shots': '0',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Celta Vigo',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '2.2472422923892736',
#   'xGBuildup': '2.0641780346632004'},
#  {'id': '7523',
#   'player_name': 'Javier Díaz',
#   'games': '1',
#   'time': '90',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Sevilla',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.15999361872673035',
#   'xGBuildup': '0.15999361872673035'},
#  {'id': '7526',
#   'player_name': 'Martín Zubimendi',
#   'games': '1',
#   'time': '4',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.2741062641143799',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Real Sociedad',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.2741062641143799',
#   'xGBuildup': '0'},
#  {'id': '7547',
#   'player_name': 'Moussa Wagué',
#   'games': '3',
#   'time': '223',
#   'goals': '0',
#   'xG': '0.09280946850776672',
#   'assists': '0',
#   'xA': '0.3279886841773987',
#   'shots': '1',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0.09280946850776672',
#   'xGChain': '0.9541059546172619',
#   'xGBuildup': '0.7308296374976635'},
#  {'id': '7548',
#   'player_name': 'Riqui Puig',
#   'games': '2',
#   'time': '157',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.5362415611743927',
#   'shots': '0',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.653629794716835',
#   'xGBuildup': '0.21019772440195084'},
#  {'id': '7549',
#   'player_name': 'Abel Ruiz',
#   'games': '1',
#   'time': '20',
#   'goals': '0',
#   'xG': '0.26430803537368774',
#   'assists': '0',
#   'xA': '0.11297111213207245',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0.26430803537368774',
#   'xGChain': '0.40181243419647217',
#   'xGBuildup': '0.024533284828066826'},
#  {'id': '7555',
#   'player_name': 'Miguel Marí',
#   'games': '2',
#   'time': '68',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Eibar',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '7586',
#   'player_name': 'Álex Collado',
#   'games': '1',
#   'time': '85',
#   'goals': '0',
#   'xG': '0.12811274826526642',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0.12811274826526642',
#   'xGChain': '0.18404154479503632',
#   'xGBuildup': '0.0559287965297699'},
#  {'id': '7604',
#   'player_name': 'Alejandro Catena',
#   'games': '2',
#   'time': '178',
#   'goals': '0',
#   'xG': '0.13818521797657013',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Rayo Vallecano',
#   'npg': '0',
#   'npxG': '0.13818521797657013',
#   'xGChain': '0.6171621009707451',
#   'xGBuildup': '0.6171621009707451'},
#  {'id': '7609',
#   'player_name': 'Carles Pérez',
#   'games': '1',
#   'time': '16',
#   'goals': '0',
#   'xG': '0.07735417038202286',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Barcelona',
#   'npg': '0',
#   'npxG': '0.07735417038202286',
#   'xGChain': '0.07735417038202286',
#   'xGBuildup': '0'}]

# %%
folder_creation("EPL", "2019")

# %%
parse_league_data("EPL" , "2018")

# %%
if not os.path.isdir("Epl"):
        os.mkdir("Epl")

# %%
if not os.path.isdir("Epl"):
    m = os.path.join("epl","2019")
    os.mkdir(m)

# %%
leagues = ["EPL", "La_liga", "Bundesliga", "Serie_A", "Ligue_1"]
years = ["2014", "2015", "2016", "2017", "2018", "2019"]

# %%
for league in leagues:
    for year in years:
        parse_league_data(league,year)
